# %%
from __future__ import print_function
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

# %%
# X and Y data
x_train = [1,2,3]
y_train = [1,2,3]

# Use tensorflow Variable(Trainable) 
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x_train * W + b

# %%
#cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
#launch the graph in a sesstion
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step,sess.run(cost),sess.run(W),sess.run(b))
# Out:
# 0 3.6378152 [-0.13952571] [0.6140782]
# 20 0.14563136 [0.53886414] [0.8600853]
# 40 0.10362941 [0.62003237] [0.845837]
# 60 0.093858205 [0.6435547] [0.8085778]
# 80 0.08524117 [0.66084576] [0.77081484]
# 100 0.07741735 [0.6768362] [0.7346119]
# 120 0.07031167 [0.6920286] [0.70009]
# 140 0.06385819 [0.7065026] [0.66718847]
# 160 0.05799699 [0.720296] [0.6358329]
# 180 0.052673783 [0.7334411] [0.6059511]
# 200 0.04783915 [0.7459684] [0.5774736]
# 220 0.0434483 [0.7579069] [0.5503345]
# 240 0.03946044 [0.76928437] [0.5244708]
# 260 0.035838615 [0.7801273] [0.4998225]
# 280 0.0325492 [0.79046047] [0.47633263]
# 300 0.029561678 [0.80030805] [0.45394674]
# 320 0.026848415 [0.8096928] [0.43261293]
# 340 0.024384141 [0.8186366] [0.4122817]
# 360 0.022146078 [0.82715994] [0.392906]
# 380 0.020113407 [0.8352828] [0.37444082]
# 400 0.01826734 [0.84302396] [0.35684353]
# 420 0.016590694 [0.8504012] [0.34007323]
# 440 0.015067915 [0.8574318] [0.32409108]
# 460 0.013684926 [0.864132] [0.30885997]
# 480 0.012428888 [0.8705172] [0.29434475]
# 500 0.011288094 [0.8766025] [0.2805116]
# 520 0.010252046 [0.88240165] [0.2673286]
# 540 0.009311068 [0.8879285] [0.25476512]
# 560 0.0084564565 [0.89319533] [0.24279211]
# 580 0.0076802857 [0.8982148] [0.23138177]
# 600 0.006975375 [0.9029983] [0.22050768]
# 620 0.0063351425 [0.90755695] [0.21014462]
# 640 0.0057536713 [0.91190153] [0.2002686]
# 660 0.005225582 [0.9160418] [0.1908567]
# 680 0.0047459477 [0.9199876] [0.18188709]
# 700 0.004310346 [0.9237479] [0.17333904]
# 720 0.00391472 [0.9273314] [0.16519272]
# 740 0.0035554084 [0.9307467] [0.15742923]
# 760 0.003229086 [0.93400127] [0.15003064]
# 780 0.0029327066 [0.937103] [0.14297977]
# 800 0.0026635379 [0.9400589] [0.13626029]
# 820 0.002419064 [0.94287586] [0.12985656]
# 840 0.0021970263 [0.9455605] [0.12375377]
# 860 0.0019953738 [0.948119] [0.1179378]
# 880 0.0018122374 [0.9505572] [0.11239517]
# 900 0.0016459025 [0.9528808] [0.10711302]
# 920 0.0014948336 [0.95509523] [0.10207909]
# 940 0.0013576328 [0.9572056] [0.09728175]
# 960 0.0012330221 [0.95921683] [0.09270991]
# 980 0.0011198515 [0.9611334] [0.08835283]
# 1000 0.0010170637 [0.96296006] [0.08420053]
# 1020 0.00092371594 [0.96470076] [0.08024342]
# 1040 0.0008389352 [0.9663597] [0.0764723]
# 1060 0.0007619345 [0.9679406] [0.0728784]
# 1080 0.00069200323 [0.96944714] [0.06945346]
# 1100 0.00062848633 [0.97088313] [0.06618942]
# 1120 0.00057079975 [0.9722516] [0.06307876]
# 1140 0.0005184104 [0.9735556] [0.06011428]
# 1160 0.00047083237 [0.9747984] [0.05728916]
# 1180 0.00042761222 [0.9759828] [0.05459678]
# 1200 0.00038836754 [0.9771115] [0.05203093]
# 1220 0.0003527211 [0.9781872] [0.04958566]
# 1240 0.00032034673 [0.9792123] [0.04725531]
# 1260 0.0002909451 [0.9801893] [0.04503451]
# 1280 0.0002642415 [0.9811203] [0.04291802]
# 1300 0.00023998706 [0.98200756] [0.04090102]
# 1320 0.00021795985 [0.9828532] [0.03897882]
# 1340 0.0001979537 [0.983659] [0.03714693]
# 1360 0.00017978536 [0.98442703] [0.03540115]
# 1380 0.00016328314 [0.98515886] [0.03373739]
# 1400 0.00014829647 [0.9858564] [0.03215184]
# 1420 0.00013468403 [0.98652107] [0.03064079]
# 1440 0.00012232178 [0.98715454] [0.02920078]
# 1460 0.00011109454 [0.9877582] [0.02782844]
# 1480 0.000100899866 [0.9883336] [0.0265206]
# 1500 9.1638205e-05 [0.9888818] [0.02527422]
# 1520 8.322639e-05 [0.98940426] [0.02408645]
# 1540 7.5588956e-05 [0.9899021] [0.02295459]
# 1560 6.865075e-05 [0.9903769] [0.02187581]
# 1580 6.2348816e-05 [0.9908291] [0.0208477]
# 1600 5.6627006e-05 [0.99126005] [0.01986791]
# 1620 5.1428942e-05 [0.99167085] [0.01893418]
# 1640 4.6709418e-05 [0.9920623] [0.01804433]
# 1660 4.2421958e-05 [0.99243534] [0.01719632]
# 1680 3.8527953e-05 [0.9927908] [0.01638814]
# 1700 3.4992645e-05 [0.9931296] [0.01561796]
# 1720 3.1780266e-05 [0.99345255] [0.01488398]
# 1740 2.886293e-05 [0.9937602] [0.0141845]
# 1760 2.6213747e-05 [0.9940535] [0.01351787]
# 1780 2.3808303e-05 [0.99433297] [0.01288255]
# 1800 2.1622596e-05 [0.9945993] [0.0122771]
# 1820 1.9637871e-05 [0.99485314] [0.01170011]
# 1840 1.7835402e-05 [0.9950951] [0.0111502]
# 1860 1.6198626e-05 [0.99532557] [0.01062615]
# 1880 1.4711349e-05 [0.9955452] [0.01012673]
# 1900 1.3361674e-05 [0.9957546] [0.00965081]
# 1920 1.2134569e-05 [0.99595416] [0.00919725]
# 1940 1.10209885e-05 [0.9961443] [0.008765]
# 1960 1.0009684e-05 [0.9963255] [0.00835307]
# 1980 9.09051e-06 [0.99649817] [0.00796052]
# 2000 8.256012e-06 [0.99666274] [0.00758639]
